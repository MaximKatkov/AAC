# %%
# Неопределенный интеграл

# Интегрирование многочлена  Pm(x) степени m 
import numpy as np
print('Интегрирование многочлена  Pm(x) степени m\n')
coeff=[]
m = int(input('Введите степень полинома m ='))
lim = []
for i in range(m+1):
    coeff.append(float(input('Введите коэффициент многочленна а = ')))
    
print('\nПодынтегральная функция:\nf = ',end='')
for i in range(m + 1):
    if i == m:
        print(coeff[i],'*x^(',m-i,')')
        break
    print(coeff[i],'*x^(',m-i,') +',end=' ')
    
print('\nПервообразная функция:\nF = ',end='')
for i in range(m + 1):
    if i == m:
        print(coeff[i] / (m-i+1),'*x^(',m-i+1,')')
        break
    print(coeff[i] / (m-i+1),'*x^(',m-i+1,') +',end=' ')
    
x = float(input('\nВведите x для нахождения значения функции'))
c = float(input('\nВведите константу интегрирования C='))

f_x=0
for i in range(m + 1):
    if i == m:
        f_x+=(coeff[i] / (m-i+1))*x**(m-i+1)
        break
    f_x+=(coeff[i] / (m-i+1))*x**(m-i+1)
    
print('\nЗначение функции в точке x=',x,' F(x)=',f_x+c)

# Триганометрическая функция sin(ax+b)
print('**********************************************************************')
print('\nИнтегрирование Триганометрической функции sin(ax+b)\n')
coeff=[]
for i in range(2):
    coeff.append(float(input('Введите коэффициент a = ')))
    
print('\nПодынтегральная функция:\nf = sin( ',end='')
for i in range(2):
    if i == 1:
        print(coeff[i],')')
        break
    print(coeff[i],'*x +',end='')
    
print('\nПервообразная функция:\nF = ',-1/coeff[0],'*cos( ',end='') 
for i in range(2):
    if i == 1:
        print(coeff[i],')')
        break
    print(coeff[i],'*x +',end='')
    
x = float(input('\nВведите x для нахождения значения функции'))
c = float(input('\nВведите константу интегрирования C='))
f_x= -1 / coeff[0] * np.cos(coeff[0] * x + coeff[1])
print('\nЗначение функции в точке x=',x,' F(x)=',f_x+c)

    

# Дробная функция
print('**********************************************************************')
print('\nИнтегрирование Дробной функции 1/(ax^2 + bx + c)\n')
coeff=[]
for i in range(3):
    coeff.append(float(input('Введите коэффициент а = ')))
    
print('\nПодынтегральная функция:\nf = 1/( ',end='')
for i in range(3):
    if i == 2:
        print(coeff[i],')')
        break
    print(coeff[i],'*x^(',2-i,') +',end='')
a1=(((4*coeff[0]*coeff[2]-coeff[1]**(0.5))/coeff[0])**(0.5))*((coeff[0])**(0.5))

print('\nПервообразная функция:\nF = ',2*a1/(4*coeff[0]*coeff[2]-coeff[1]**(0.5)),'arctg( ',end='') 
print(2/a1,'*(',coeff[0],'*x +',coeff[1],') )')

x = float(input('\nВведите x для нахождения значения функции'))
c = float(input('\nВведите константу интегрирования C='))
f_x=2*a1/(4*coeff[0]*coeff[2]-coeff[1]**(0.5))*np.arctan((2/a1) * coeff[0] * x + coeff[1])
print('\nЗначение функции в точке x=',x,' F(x)=',f_x+c)
# Out:
# Интегрирование многочлена  Pm(x) степени m
#
# Введите степень полинома m =2
# Введите коэффициент многочленна а = 4
# Введите коэффициент многочленна а = 2
# Введите коэффициент многочленна а = 1
#
# Подынтегральная функция:
# f = 4.0 *x^( 2 ) + 2.0 *x^( 1 ) + 1.0 *x^( 0 )
#
# Первообразная функция:
# F = 1.3333333333333333 *x^( 3 ) + 1.0 *x^( 2 ) + 1.0 *x^( 1 )
#
# Введите x для нахождения значения функции1
#
# Введите константу интегрирования C=3
#
# Значение функции в точке x= 1.0  F(x)= 6.333333333333333
# **********************************************************************
#
# Интегрирование Триганометрической функции sin(ax+b)
#
# Введите коэффициент a = 2
# Введите коэффициент a = 4
#
# Подынтегральная функция:
# f = sin( 2.0 *x +4.0 )
#
# Первообразная функция:
# F =  -0.5 *cos( 2.0 *x +4.0 )
#
# Введите x для нахождения значения функции1
#
# Введите константу интегрирования C=4
#
# Значение функции в точке x= 1.0  F(x)= 3.519914856674817
# ...
