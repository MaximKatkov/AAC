# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.plot([1, 4,-5, 7,6], label='Plot 1')
plt.xlabel('день', fontsize=20,color='blue' )
plt.ylabel('температура')
plt.title('Дневная температура октября')
plt.legend()
plt.grid()
plt.text(3,6,'Тепло')
# Out:
# Text(3, 6, 'Тепло')

# %%
plt.plot([1, 4,-5, 7,6], label='Температура')
plt.xlabel('день', fontsize=10,color='blue' )
plt.ylabel('температура')
plt.title('Дневная температура октября')
plt.legend()
plt.grid()
plt.text(3,6,'max')
# Out:
# Text(3, 6, 'max')

# %%
x=[-1,2, 4, 6, 7,9 ]
y=[1, -2, 3, 5, 4,7 ]
plt.plot(x,y ,color='red',linewidth=10,alpha=0.5, label='Plot 2')
plt.xlabel('день', fontsize=10,color='blue' )
plt.ylabel('температура')
plt.title('Дневная температура октября')
plt.legend()
plt.grid(True)
plt.text(7,6,'max')
# Out:
# Text(7, 6, 'max')

# %%
x=[-1,2, 4, 6, 7,9 ]
y=[1, -2, 3, 5, 4,7 ]
#'b', 'r', 'g','m','y','k','w'
# '-','--','.-','*',':'
plt.plot(x,y ,'r--', linewidth=3, label='Plot 2')#linestyle= '--'
plt.xlabel('день', fontsize=10,color='blue' )
plt.ylabel('температура')
plt.title('Дневная температура октября ')
plt.legend()
plt.grid(True)
plt.text(3,6,'max')
# Out:
# Text(3, 6, 'max')

# %%
x=[-1,2, 4, 6, 7,9 ]
y1=[3, -2.5, 3, 5, 4,7 ]
y2=[-i*1.5+1 for i in y1]
y3=[(i+1)*1.5-1 for i in y2]
y4=[(-i+2)*1.5+2 for i in y3]
ll=['y1','y2', 'y3','y4','y']
# '-','--','.-','*',':'
plt.plot(x,y1,'-', x,y2,'--', x,y3,':', x,y4,'-.', x,y,'*')
plt.legend(ll)

# %%
#plt.plot(x,y,'-', x,y1,'--', x,y2,':', x,y3,'-.', x,y4,'*')
#'b', 'r', 'g','m','y','k','w'
#'o','x', 'd'
plt.plot(x,y,'md')
plt.plot(x,y2,'>')
plt.plot(x,y3,'gp')
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(2,2,1)
plt.plot(x,y, 'r')
plt.subplot(2,2,2)
plt.plot(x,y1)
plt.subplot(2,2,3)
plt.plot(x,y2,'g')
plt.subplot(2,2,4)
plt.plot(x,y3,'k')

# %%
plt.figure(figsize=(14,6))
plt.plot(x,y1,'h--r', alpha=0.7, label='Первый', lw=10, mec='g', mew=5, ms=20)
plt.plot(x,y2,'v-.g',  label='Второй', lw=2, mec='r', mew=3, ms=15)
plt.legend()

# %%
x=np.arange(0,6,0.02)
y=np.cos(x*np.pi)

# %%
plt.plot(x,y,'g')
plt.fill_between(x,y)

# %%
plt.plot(x,y,'g')
plt.fill_between(x,y,where=(y>0.3)|(y<-0.5))

# %%
plt.plot(x,y,'g')
plt.fill_between(x,y,where=(y>0.2))

# %%
plt.plot(x,y,'g')
plt.fill_between(x,y,-2)

# %%
ys=np.sin(x*np.pi)
plt.plot(x,y,'g')
plt.fill_between(x,y,where=(y>0.3), color='r',alpha=0.1 )
plt.fill_between(x,y,where=(y<-0.3), color='m',alpha=0.2 )
plt.plot(x,ys,'g')
plt.fill_between(x,ys,where=(ys>0.3), color='b',alpha=0.4 )

# %%
x=np.arange(0,10)
y=[1,3,6,4,3,8,9,11,3,2]
plt.plot(x,y,marker='o',c='r')

# %%
a=np.arccos(0.5)

# %%
x=np.arange(0,6)
y=np.cos(x)
x1=np.arccos(y)
x1
# Out:
# array([0.        , 1.        , 2.        , 3.        , 2.28318531,
#        1.28318531])

# %% [markdown]
# # ДЗ: Построить три любые функции каждую в своем окне и три в одном

# %%
#Степ-график
x=np.arange(0,7)
y=2*x-3
where_set=['pre','post','mid']
fig, axs=plt.subplots(1,3,figsize=(18, 5))
for i, ax in enumerate(axs):
    ax.step(x,y, 'r-o', where=where_set[i])
    ax.grid()

# %%
#Стековый график
x=np.arange(0,12,1)
y1=np.array([-0.2*i**2+3*i for i in  x])
y2=np.array([-0.4*i**2+4*i for i in  x])
y3=np.array([2*i for i in  x])

# %%
labels100=['y1', 'y2','y3']
fig, ax=plt.subplots()
ax.stackplot(x, y2,y1,y3, labels=labels100)
ax.legend(loc='upper left')

# %%
ax
# Out:
# <AxesSubplot:>

# %%
plt.plot(x,y1,'-', x,y2,'--', x,y3,':')
plt.legend(labels100)

# %%
#Стем-график
plt.stem(x,y1, markerfmt='s', linefmt='g-.')
# Out:
# <StemContainer object of 3 artists>

# %%
plt.scatter(x,y1, alpha=0.5)
plt.scatter(x,y2,c='g', marker='d')
plt.scatter(x,y3, s=100, c='m', marker='h', linewidth=2, edgecolors='y')
plt.show()

# %%
import matplotlib.colors as mcolors
bc=mcolors.BASE_COLORS

# %%
x=np.arange(0,2*np.pi,0.2)
y=np.sin(x)

# %%
nom_set=np.random.randint(0,len(bc)-1,len(x))

# %%
sizes=nom_set*35

# %%
colors=[list(bc.keys())[i] for i in nom_set]

# %%
plt.scatter(x,y, s=sizes, alpha=0.4, c=colors, linewidths=2,
           edgecolors="face")
plt.plot(x,y,'g--')

# %% [markdown]
# # диаграммы

# %%
np.random.seed(2023)
groupP=[f"Gr{i}" for i in range(7)]

# %%
groupP
# Out:
# ['Gr0', 'Gr1', 'Gr2', 'Gr3', 'Gr4', 'Gr5', 'Gr6']

# %%
counts=np.random.randint(3,12,len(groupP))
counts
# Out:
# array([10,  9, 10,  4,  6,  7,  7])

# %%
plt.bar(groupP, counts)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.barh(groupP, counts)
# Out:
# <BarContainer object of 7 artists>

# %%
import matplotlib.colors as pltcolor

# %%
baseC=pltcolor.BASE_COLORS
baseC
# Out:
# {'b': (0, 0, 1),
#  'g': (0, 0.5, 0),
#  'r': (1, 0, 0),
#  'c': (0, 0.75, 0.75),
#  'm': (0.75, 0, 0.75),
#  'y': (0.75, 0.75, 0),
#  'k': (0, 0, 0),
#  'w': (1, 1, 1)}

# %%
baseC['o']=(0.5, 0.1,0.8)

# %%
baseC
# Out:
# {'b': (0, 0, 1),
#  'g': (0, 0.5, 0),
#  'r': (1, 0, 0),
#  'c': (0, 0.75, 0.75),
#  'm': (0.75, 0, 0.75),
#  'y': (0.75, 0.75, 0),
#  'k': (0, 0, 0),
#  'w': (1, 1, 1),
#  'o': (0.5, 0.1, 0.8)}

# %%
groupP=[f"P{i}" for i in range(10)]

# %%
counts=np.random.randint(0, len(baseC),len(groupP))

# %%
width=counts*0.1
colors=[["r","g","b"][int(np.random.randint(0,3,1))] for _ in counts]

# %%
colors=['b', 'y','r','g','k', 'b', 'y','r','g','y']

# %%
plt.bar(groupP,counts, width=width, alpha=0.5, bottom=2, color=colors,
       edgecolor='k', linewidth=2)
# Out:
# <BarContainer object of 10 artists>

# %%
groupP=[f"P{i}" for i in range(7)]

# %%
s1=[23, 12, 21, 14, 18, 7, 19]
s2=[13, 22, 24, 10, 11, 5, 14]
width=0.4
x=np.arange(len(groupP))
fig, ax =plt.subplots()
prs1=ax.bar(x-width/2, s1, width, label='gr1')
prs2=ax.bar(x+width/2, s2, width, label='gr2')
ax.set_xticks(x)
ax.set_xticklabels(groupP)
ax.legend()

# %%
s1=[23, 12, 21, 14, 18, 7, 19]
s2=[13, 22, 24, 10, 11, 5, 14]
width=0.4
x=np.arange(len(groupP))
fig, ax =plt.subplots()
prs1=ax.bar(x-width/3, s1, width, label='gr1', alpha=0.5)
prs2=ax.bar(x+width/3, s2, width, label='gr2', alpha=0.5)
ax.set_xticks(x)
ax.set_xticklabels(groupP)
ax.legend()

# %% [markdown]
#  ДЗ Для 7 человек построить диаграмму для роста и веса, цвета разные
# с именами.
# Взять вектор дохода и построить круговую диаграмму

# %%
valm=[13,34,15,21,10]
labels=['1', '2', '3', '4','5']
explode=[0.1, 0, 0,0.5,0]
plt.pie(valm, labels=labels, autopct='%1.1f%%', explode=explode,
       wedgeprops={'lw':1, 'ls':'--', 'edgecolor':'c'}, 
        rotatelabels=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2acec42d3d0>,
# ...
#  [Text(1.086137407416286, 0.510201462376412, '1'),
#   Text(-0.48443359952333903, 0.9875849774337707, '2'),
#   Text(-0.9432028235317437, -0.5660109837112234, '3'),
#   Text(0.2955617054581168, -1.572464078529837, '4'),
#   Text(1.0378325945623892, -0.3645593307870474, '5')],
#  [Text(0.6335801543261667, 0.2976175197195736, '14.0%'),
#   Text(-0.26423650883091215, 0.5386827149638749, '36.6%'),
#   Text(-0.514474267380951, -0.30873326384248545, '16.1%'),
#   Text(0.20319867250245527, -1.081069053989263, '22.6%'),
#   Text(0.5660905061249395, -0.1988505440656622, '10.8%')])

# %%
data=np.array([[4,12,6],[11,5,8],[3,7,9],[8,6,2]])
offset=0.4
cmap=plt.get_cmap("tab20b")
pcolors=cmap(np.array([2,9,15,24]))
smcolors=cmap(np.array([1,3,5,10,12,14,17,19,22,26,28,32]))
plt.pie(data.sum(axis=1), radius=1, colors=pcolors,
       wedgeprops=dict(width=offset, edgecolor='w'))
plt.pie(data.flatten(), radius=1-offset, colors=smcolors,
       wedgeprops=dict(width=offset, edgecolor='w'))
# Out:
# ([<matplotlib.patches.Wedge at 0x2acec49aa90>,
# ...
#  [Text(0.6520733005368139, 0.10198240400689704, ''),
#   Text(0.4711936221372879, 0.46214345224956155, ''),
#   Text(0.06389516745073626, 0.656899845925117, ''),
#   Text(-0.35191492145408065, 0.5583510437511229, ''),
#   Text(-0.610977813153572, 0.24961192245980346, ''),
#   Text(-0.6555373178367097, -0.0766213085469883, ''),
#   Text(-0.565070160292525, -0.341021574019856, ''),
#   Text(-0.39412467924380606, -0.5294013007265538, ''),
#   Text(-0.012798286787501731, -0.659875900344379, ''),
#   Text(0.39412466685227365, -0.5294013099517079, ''),
#   Text(0.6109778189961605, -0.24961190815883552, ''),
#   Text(0.6580153411411839, -0.051144998023769976, '')])

# %%
from PIL import Image

# %%
img=Image.open(r'Z:\KursP2022\G21e1\Primer\Crazy_Frog.jpg')

# %%
plt.imshow(img)

# %%
img.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-859141e1bca2> in <module>
# ----> 1 img.size
#
# NameError: name 'img' is not defined

# %% [markdown]
# Список цветовых карт
# cmap: plasma, spring, summer, winter, autumn, rainbow, RdYlBu, tab20b, PuOr, magma, inferno , cividis, viridis

# %%
np.random.seed(7564)
data=np.random.randn(10,12)
plt.imshow(data, cmap = 'viridis', interpolation='gaussian',
           extent=(0,40,0,30))
plt.colorbar()

# %%
data1=np.random.rand(10,12)
plt.pcolormesh(data1, cmap='plasma',edgecolor='k')

# %% [markdown]
# # 3D изображения

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
t=np.linspace(-2*np.pi,2*np.pi,100)
x=np.cos(3*t)
y=np.sin(2*t)
z=np.sin(2*t)
#x=y=z=t
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z, 'r')

# %%
y=np.random.randint(-5,5,70)
x=np.random.randint(-7,7,70)
z=np.random.randint(0,10,70)
s=np.random.randint(40,180,70)
cmap=plt.get_cmap("plasma")
smcolors=cmap(np.random.randint(1,25,70))
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d',alpha=0.5)
ax.scatter(x,y,z,s=s,  c=smcolors)

# %% [markdown]
# fig=plt.figure()
# ax=fig.add_subplot(111, projection='3d')
# ax.plot_wireframe(x,y,z)

# %%
p,q=np.mgrid[0:2*np.pi:30j,0:2*np.pi:20j ]
x=np.sin(q)*np.cos(p)
y=np.sin(p)*np.sin(0.5*q)
z=np.cos(0.5*q)
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.plot_surface(x,y,z, cmap='plasma')
#ax.plot_wireframe(x,y,z)

# %%
u=np.linspace(-6,6,30)
v=np.linspace(-6,6,30)
[x1,y1]=np.meshgrid(u,v )
#z=x1**2+y1**2
#z=x1**2-y1**2
z=np.sin(0.5*x1)*np.cos(0.5*y1)
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.plot_surface(x1,y1,z, cmap='spring', shade=False)

#ax.plot_wireframe(x,y,z)

# %%
import matplotlib.animation as anima
from PIL import Image

# %%
import os
os.chdir(r'Z:\KursP2022\G21e1\Primer')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\2960428195.py in <module>
#       1 import os
# ----> 2 os.chdir(r'Z:\KursP2022\G21e1\Primer')
#
# FileNotFoundError: [WinError 3] Системе не удается найти указанный путь: 'Z:\\KursP2022\\G21e1\\Primer'

# %%
def anim(i):
    ax.clear()
    line = ax.plot(t, np.sin(t+i))
    return line

# %%
np.pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\4136878702.py in <module>
# ----> 1 np.pi
#
# NameError: name 'np' is not defined

# %%
t=np.linspace(-np.pi,np.pi,200)
fig,ax=plt.subplots()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\1213252523.py in <module>
# ----> 1 t=np.linspace(-np.pi,np.pi,200)
#       2 fig,ax=plt.subplots()
#
# NameError: name 'np' is not defined

# %%
fasa=np.linspace(-np.pi, np.pi, 50)
sanima=anima.FuncAnimation(fig, anim, frames=fasa, 
                           interval=10,repeat=False )
sanima.save('runsin.gif', writer='imagemagick', fps=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\1545811183.py in <module>
# ----> 1 fasa=np.linspace(-np.pi, np.pi, 50)
#       2 sanima=anima.FuncAnimation(fig, anim, frames=fasa,
#       3                            interval=10,repeat=False )
#       4 sanima.save('runsin.gif', writer='imagemagick', fps=10)
#
# NameError: name 'np' is not defined

# %%
fasa=np.linspace(-np.pi, np.pi, 10)
u=np.linspace(-6,6,30)
v=np.linspace(-6,6,30)
[x1,y1]=np.meshgrid(u,v )
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')

#ax.plot_wireframe(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\1369776395.py in <module>
# ----> 1 fasa=np.linspace(-np.pi, np.pi, 10)
#       2 u=np.linspace(-6,6,30)
#       3 v=np.linspace(-6,6,30)
#       4 [x1,y1]=np.meshgrid(u,v )
#       5 fig=plt.figure()
#
# NameError: name 'np' is not defined

# %%
def anim1(phi):
    z=np.sin(0.5*x1+phi)*np.cos(0.5*y1+phi)
    #ax.clear()
    ax=fig.add_subplot(111, projection='3d')
    line=ax.plot_surface(x1,y1,z, cmap='spring', shade=False)
    return line

# %%
sanima1=anima.FuncAnimation(fig, anim1, frames=fasa, 
                           interval=5,repeat=False )
sanima1.save('runsd.gif', writer='imagemagick', fps=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\1015500576.py in <module>
# ----> 1 sanima1=anima.FuncAnimation(fig, anim1, frames=fasa,
#       2                            interval=5,repeat=False )
#       3 sanima1.save('runsd.gif', writer='imagemagick', fps=10)
#
# NameError: name 'fig' is not defined

# %% [markdown]
# ДЗ Создать gif файл с любой поверхностью в движении
